# %%
# Importa
import pandas as pd
import folium
from geopy.geocoders import Nominatim
import os
from tqdm import tqdm
import sys
from folium.plugins import Search

# %%
# Carica il file CSV
file_path = './consultori-roma-mail-orari.csv'
data = pd.read_csv(file_path)

# %%
# Crea l'oggetto geocoder
geolocator = Nominatim(user_agent="consultori_mapper")

# %%
# Creazione della mappa di Roma
roma_map = folium.Map(location=[41.9028, 12.4964], zoom_start=12)  # Coordinate centrali di Roma

# %%
# Definisci colori per le diverse ASL
asl_colors = {
    'ROMA 1': 'blue',
    'ROMA 2': 'green',
    'ROMA 3': 'red',
    'ROMA 4': 'purple',
    'ROMA 5': 'orange',
    'ROMA 6': 'darkred'
}

icon_height = 37
icon_width = 35

# %%
# Crea feature group per tenere tutti i marker
marker_group = folium.FeatureGroup(name="Consultori")

# %%
# Aggiunta di marker per ogni consultorio
failed_entries = [] # Inizializza array per conservare le entries non caricate

for index, row in tqdm(data.iterrows(), total=len(data), desc="Aggiunta marker consultori", file=sys.stdout, ncols=100):
    print(data.columns)
    nome_consultorio = row['Consultorio Familiare']
    asl = row['ASL']
    raw_indirizzo = row['Indirizzo']
    cleaned_df = clean_indirizzo_column(df, column_name='Indirizzo')

    indirizzo = raw_indirizzo.lower().replace('snc', 's.n.c.').replace('c/o', '').replace('l.go', 'largo').replace("(C/O POL BARBERINI)","").strip()
    telefono = row['Telefono']
    orari = row['Orari']
    contact = row['Email/sito']

    # Ottieni le coordinate usando il geocoder
    try:
        location = geolocator.geocode(indirizzo + ", Italy")
        if location:
            lat, lon = location.latitude, location.longitude

            # Creazione del contenuto del popup
            if '@' in contact or contact == "n/d":
                popup_content = f"""
                          <h4>{nome_consultorio}</h4>
                          <i>{asl}</i>
                          <br>
                          <ul>
                              <li style='list-style-type: square'><b>Indirizzo</b>: {raw_indirizzo}
                              <li style='list-style-type: square'><b>Telefono</b>: {telefono}
                              <li style='list-style-type: square'><b>Email/sito</b>: {contact}
                          </ul>
                          <p>Orari apertura: <br>
                          {orari}
                          </p>
                            """
            else:
                popup_content = f"""
                          <h4>{nome_consultorio}</h4>
                          <i>{asl}</i>
                          <br>
                          <ul>
                              <li style='list-style-type: square'><b>Indirizzo</b>: {raw_indirizzo}
                              <li style='list-style-type: square'><b>Telefono</b>: {telefono}
                              <li style='list-style-type: square'><b>Email/sito</b>: <a href="https://{contact}" target="_blank">{contact}</a>
                          </ul>
                          <p>Orari apertura: <br>
                          {orari}
                          </p>
                            """

            # Construct the file path for the icon
            icon_image = f"./{asl_colors.get(asl)}.png"  # Example: "./red.svg"
            
            # Create a custom icon
            icon = folium.CustomIcon(
                icon_image,
                icon_size=(icon_width, icon_height),  # Adjust size as per your SVG dimensions
                icon_anchor=(22, 94),
                popup_anchor=(-3, -76),
            )
            
            # Add a marker with the custom icon
            folium.Marker(
                location=[lat, lon],
                popup=folium.Popup(popup_content, max_width=500),
                icon=icon  # Use the custom icon here
            ).add_to(marker_group)

            # Clear the line to avoid clutter
            sys.stdout.write("\033[F")
        # se un'entry non è stata geolocalizzata, aggiungila al'elenco dei fallimenti
        else: 
            print(f"Geocoding failed: {indirizzo}")
            failed_entries.append(row)
    except Exception as e:
        print(f"Error for {indirizzo}: {e}")
        failed_entries.append(row)

# Add a search bar linked to the feature group
Search(
    layer=marker_group,
    search_label="tooltip",  # Use marker tooltips (consultorio names) as searchable labels
    placeholder="Cerca consultorio...",
    collapsed=False  # Keep the search bar expanded
).add_to(roma_map)

# Add the feature group to the map
marker_group.add_to(roma_map)
# Out:
# Aggiunta marker consultori:   0%|                                            | 0/83 [00:00<?, ?it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: piazza s. m. della pieta` 5, 00135, roma
# Aggiunta marker consultori:   1%|▍                                   | 1/83 [00:00<01:18,  1.05it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:   2%|▊                                   | 2/83 [00:01<01:15,  1.08it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:   4%|█▎                                  | 3/83 [00:02<01:04,  1.24it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:   5%|█▋                                  | 4/83 [00:03<01:00,  1.30it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:   6%|██▏                                 | 5/83 [00:03<00:50,  1.55it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:   7%|██▌                                 | 6/83 [00:04<00:45,  1.68it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:   8%|███                                 | 7/83 [00:04<00:42,  1.81it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  10%|███▍                                | 8/83 [00:04<00:36,  2.06it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  11%|███▉                                | 9/83 [00:05<00:42,  1.72it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  12%|████▏                              | 10/83 [00:05<00:33,  2.19it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  13%|████▋                              | 11/83 [00:06<00:41,  1.75it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  14%|█████                              | 12/83 [00:07<00:41,  1.71it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  16%|█████▍                             | 13/83 [00:08<00:42,  1.64it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  17%|█████▉                             | 14/83 [00:08<00:35,  1.96it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  18%|██████▎                            | 15/83 [00:08<00:37,  1.82it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  19%|██████▋                            | 16/83 [00:09<00:32,  2.07it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  20%|███████▏                           | 17/83 [00:09<00:35,  1.87it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  22%|███████▌                           | 18/83 [00:10<00:32,  2.03it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  23%|████████                           | 19/83 [00:11<00:34,  1.84it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  24%|████████▍                          | 20/83 [00:11<00:27,  2.27it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  25%|████████▊                          | 21/83 [00:13<00:54,  1.14it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  27%|█████████▎                         | 22/83 [00:13<00:46,  1.32it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  28%|█████████▋                         | 23/83 [00:15<01:05,  1.10s/it]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  29%|██████████                         | 24/83 [00:15<00:51,  1.14it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  30%|██████████▌                        | 25/83 [00:16<00:43,  1.33it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  31%|██████████▉                        | 26/83 [00:16<00:41,  1.39it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  33%|███████████▍                       | 27/83 [00:17<00:31,  1.79it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via resede acacie 1, 00171, roma
# Aggiunta marker consultori:  34%|███████████▊                       | 28/83 [00:17<00:33,  1.66it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via t. agudio,5, 00100, roma
# Aggiunta marker consultori:  35%|████████████▏                      | 29/83 [00:18<00:33,  1.63it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  36%|████████████▋                      | 30/83 [00:18<00:29,  1.80it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via rizzieri,226, 00173, roma
# Aggiunta marker consultori:  37%|█████████████                      | 31/83 [00:19<00:33,  1.58it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  39%|█████████████▍                     | 32/83 [00:20<00:27,  1.88it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  40%|█████████████▉                     | 33/83 [00:20<00:29,  1.69it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: lungomare p. toscanelli, 230, 00121, roma
# Aggiunta marker consultori:  41%|██████████████▎                    | 34/83 [00:21<00:29,  1.67it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via della pineta di fregene,76, 00054, fiumicino
# Aggiunta marker consultori:  42%|██████████████▊                    | 35/83 [00:21<00:28,  1.67it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  43%|███████████████▏                   | 36/83 [00:23<00:45,  1.04it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: borgo g. da montesarchio ,76, 00125, roma
# Aggiunta marker consultori:  45%|███████████████▌                   | 37/83 [00:24<00:40,  1.15it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via s. belfanti, 76 a, 00166, roma
# Aggiunta marker consultori:  46%|████████████████                   | 38/83 [00:24<00:33,  1.35it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via a. colautti 28/30, 00152, roma
# Aggiunta marker consultori:  47%|████████████████▍                  | 39/83 [00:25<00:33,  1.32it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  48%|████████████████▊                  | 40/83 [00:26<00:30,  1.40it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  49%|█████████████████▎                 | 41/83 [00:26<00:26,  1.59it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via brugnato 2, 00148, roma
# Aggiunta marker consultori:  51%|█████████████████▋                 | 42/83 [00:27<00:26,  1.54it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  52%|██████████████████▏                | 43/83 [00:27<00:23,  1.74it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: largo  e. quadrelli, 5, 00148, roma
# Aggiunta marker consultori:  53%|██████████████████▌                | 44/83 [00:28<00:25,  1.54it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  54%|██████████████████▉                | 45/83 [00:28<00:19,  1.93it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  55%|███████████████████▍               | 46/83 [00:29<00:20,  1.84it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via n. bixio, 27, 00055, ladispoli
# Aggiunta marker consultori:  57%|███████████████████▊               | 47/83 [00:30<00:21,  1.68it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  58%|████████████████████▏              | 48/83 [00:30<00:21,  1.66it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  59%|████████████████████▋              | 49/83 [00:31<00:22,  1.50it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via marco polo, s.n.c., 00061, anguillara sabazia
# Aggiunta marker consultori:  60%|█████████████████████              | 50/83 [00:32<00:23,  1.40it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  61%|█████████████████████▌             | 51/83 [00:32<00:20,  1.53it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  63%|█████████████████████▉             | 52/83 [00:33<00:23,  1.34it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via regina margherita, s.n.c., 00060, formello
# Aggiunta marker consultori:  64%|██████████████████████▎            | 53/83 [00:34<00:23,  1.27it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via tiberina n.71 angolo capocroce, 00065, fiano romano
# Aggiunta marker consultori:  65%|██████████████████████▊            | 54/83 [00:35<00:22,  1.31it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via g. roncacci, n.78, 00067, morlupo
# Aggiunta marker consultori:  66%|███████████████████████▏           | 55/83 [00:36<00:21,  1.28it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  67%|███████████████████████▌           | 56/83 [00:38<00:31,  1.16s/it]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Error for via iv novembre, 2, 00013, fonte nuova: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=via+iv+novembre%2C+2%2C+00013%2C+fonte+nuova%2C+Italy&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Aggiunta marker consultori:  69%|████████████████████████           | 57/83 [00:41<00:47,  1.81s/it]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via g. pascoli, 54, 00012, guidonia montecelio
# Aggiunta marker consultori:  70%|████████████████████████▍          | 58/83 [00:42<00:38,  1.53s/it]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  71%|████████████████████████▉          | 59/83 [00:43<00:30,  1.26s/it]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: piazza salvo d'acquisto, 1, 00018, palombara sabina
# Aggiunta marker consultori:  72%|█████████████████████████▎         | 60/83 [00:43<00:24,  1.06s/it]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  73%|█████████████████████████▋         | 61/83 [00:43<00:17,  1.28it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: largo mazzini, 5, 00028, subiaco
# Aggiunta marker consultori:  75%|██████████████████████████▏        | 62/83 [00:44<00:17,  1.18it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via di s. francesco d'assisi s.n.c., 00025, olevano romano
# Aggiunta marker consultori:  76%|██████████████████████████▌        | 63/83 [00:46<00:23,  1.17s/it]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  77%|██████████████████████████▉        | 64/83 [00:47<00:19,  1.01s/it]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via borgo san martino s.n.c., 00039, zagarolo
# Aggiunta marker consultori:  78%|███████████████████████████▍       | 65/83 [00:48<00:15,  1.13it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: largo oberdan s.n.c., 00034, colleferro
# Aggiunta marker consultori:  80%|███████████████████████████▊       | 66/83 [00:48<00:13,  1.24it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  81%|████████████████████████████▎      | 67/83 [00:49<00:13,  1.19it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via pacinotti, 1, 00037, segni
# Aggiunta marker consultori:  82%|████████████████████████████▋      | 68/83 [00:50<00:12,  1.24it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  83%|█████████████████████████████      | 69/83 [00:50<00:08,  1.61it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via malpasso d`acqua  ospedale cartoni, 00040, rocca priora
# Aggiunta marker consultori:  84%|█████████████████████████████▌     | 70/83 [00:52<00:11,  1.08it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  86%|█████████████████████████████▉     | 71/83 [00:52<00:10,  1.12it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  87%|██████████████████████████████▎    | 72/83 [00:54<00:11,  1.06s/it]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  88%|██████████████████████████████▊    | 73/83 [00:55<00:10,  1.02s/it]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: vle xxiv maggio ,1 c\o osp marino, 00047, marino
# Aggiunta marker consultori:  89%|███████████████████████████████▏   | 74/83 [00:56<00:10,  1.20s/it]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via m. calo' 5, 00043, ciampino
# Aggiunta marker consultori:  90%|███████████████████████████████▋   | 75/83 [00:57<00:07,  1.00it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  92%|████████████████████████████████   | 76/83 [00:58<00:06,  1.13it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  93%|████████████████████████████████▍  | 77/83 [00:58<00:04,  1.30it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via galleria di sotto 6, 00041, albano laziale
# Aggiunta marker consultori:  94%|████████████████████████████████▉  | 78/83 [00:59<00:04,  1.23it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Aggiunta marker consultori:  95%|█████████████████████████████████▎ | 79/83 [01:00<00:03,  1.32it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via antonietta chigi 52, 00040, ariccia
# Aggiunta marker consultori:  96%|█████████████████████████████████▋ | 80/83 [01:00<00:02,  1.47it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via aldo moro 8/12, 00040, lanuvio
# Aggiunta marker consultori:  98%|██████████████████████████████████▏| 81/83 [01:02<00:02,  1.09s/it]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: via unione sovietica 14, 00045, genzano di roma
# Aggiunta marker consultori:  99%|██████████████████████████████████▌| 82/83 [01:03<00:00,  1.02it/s]Index(['ASL', 'Consultorio Familiare', 'Indirizzo', 'Telefono', 'Orari',
#        'Email/sito'],
#       dtype='object')
# Geocoding failed: piazza san francesco(  pol barberini), 00048, nettuno
# Aggiunta marker consultori: 100%|███████████████████████████████████| 83/83 [01:04<00:00,  1.29it/s]

# %%
# Log failed entries
if failed_entries:
    print("\nFailed geocoding entries:")
    for entry in failed_entries:
        print(entry)
# Out:
# Failed geocoding entries:
# ASL                                                                 ROMA 1
# Consultorio Familiare                 CONSULTORIO  FAMILIARE 'MONTE MARIO'
# Indirizzo                         PIAZZA S. M. DELLA PIETA` 5, 00135, ROMA
# Telefono                                                       06 60106696
# Orari                    Lun-Ven 7:30-13:30\nLun, Mar e Gio 7:30-13:30/...
# Email/sito               consultori14@aslroma1.it\nspaziogiovani14@aslr...
# Name: 0, dtype: object
# ASL                                                                 ROMA 2
# Consultorio Familiare                         CONSULTORIO FAMILIARE RESEDE
# Indirizzo                                 via Resede Acacie 1, 00171, ROMA
# Telefono                                                  06 41436002-6020
# Orari                             Lun-Ven 8:30-13:00 Mar e Mer 14:00-17:30
# Email/sito               www.aslroma2.it/index.php/servizi-on-line-citt...
# Name: 27, dtype: object
# ASL                                                                 ROMA 2
# Consultorio Familiare                         CONSULTORIO FAMILIARE AGUDIO
# Indirizzo                                     via T. Agudio,5, 00100, ROMA
# Telefono                                                       06 41436420
# Orari                                   Lun-Ven 8:30-13:00 Mer 14:00-17:30
# Email/sito               www.aslroma2.it/index.php/servizi-on-line-citt...
# Name: 28, dtype: object
# ASL                                                                ROMA 2
# Consultorio Familiare                      CONSULTORIO FAMILIARE RIZZIERI
# Indirizzo                                   via rizzieri,226, 00173, ROMA
# Telefono                                                      06 41434012
# Orari                    Lun-Ven 8:30-13:00 - Lun, Mar e Gio  14:00-17:30
# Email/sito                        poloostetrico.consultoriale@aslroma2.it
# Name: 30, dtype: object
# ASL                                                         ROMA 3
# Consultorio Familiare                  CONSULTORIO FAMILIARE OSTIA
# Indirizzo                LUNGOMARE P. TOSCANELLI, 230, 00121, ROMA
# Telefono                                               06 56483024
# Orari                    lun-ven 08:00-14:00; lun-merc 14:30-17:30
# Email/sito                           consultorio.ostia@aslroma3.it
# Name: 33, dtype: object
# ASL                                                                ROMA 3
# Consultorio Familiare                       CONSULTORIO FAMILIARE FREGENE
# Indirizzo                VIA DELLA PINETA DI FREGENE,76, 00054, FIUMICINO
# Telefono                                                      06 56484201
# Orari                           lun-ven 08:00-14:00; lun-merc 14:30-17:30
# Email/sito                                consultorio.fregene@aslroma3.it
# Name: 34, dtype: object
# ASL                                                         ROMA 3
# Consultorio Familiare                 CONSULTORIO FAMILIARE ACILIA
# Indirizzo                BORGO G. DA MONTESARCHIO ,76, 00125, ROMA
# Telefono                                               06 56483200
# Orari                     lun-ven 08:00-14:00; lun-gio 14:30-17:30
# Email/sito                          consultorio.acilia@aslroma3.it
# Name: 36, dtype: object
# ASL                                                        ROMA 3
# Consultorio Familiare             CONSULTORIO FAMILIARE MASSIMINA
# Indirizzo                      VIA S. BELFANTI, 76 A, 00166, ROMA
# Telefono                                              06 56486642
# Orari                    lun-ven 08:00-14:00; lun-gio 14:30-17:30
# Email/sito                      consultorio.massimina@aslroma3.it
# Name: 37, dtype: object
# ASL                                                        ROMA 3
# Consultorio Familiare            CONSULTORIO FAMILIARE MONTEVERDE
# Indirizzo                      VIA A. COLAUTTI 28/30, 00152, ROMA
# Telefono                                              06 56486131
# Orari                    lun-ven 08:00-14:00; lun-mar 14:30-17:30
# Email/sito                     consultorio.monteverde@aslroma3.it
# Name: 38, dtype: object
# ASL                                                         ROMA 3
# Consultorio Familiare                 CONSULTORIO FAMILIARE TRULLO
# Indirizzo                              VIA BRUGNATO 2, 00148, ROMA
# Telefono                                                0656485672
# Orari                    lun-ven 08:00-14:00; lun-merc 14:30-17:30
# Email/sito                          consultorio.trullo@aslroma3.it
# Name: 41, dtype: object
# ASL                                                        ROMA 3
# Consultorio Familiare              CONSULTORIO FAMILIARE CORVIALE
# Indirizzo                      L.GO  E. QUADRELLI, 5, 00148, ROMA
# Telefono                                              06 56485724
# Orari                    lun-ven 08:00-14:00; lun-mar 14:30-17:30
# Email/sito                       consultorio.corviale@aslroma3.it
# Name: 43, dtype: object
# ASL                                                                 ROMA 4
# Consultorio Familiare                      CONSULTORIO FAMILIARE LADISPOLI
# Indirizzo                               VIA N. BIXIO, 27, 00055, LADISPOLI
# Telefono                                               06 96669382-383-384
# Orari                    Lun 9:00–17:00; Mar 9:00–17:00; Mer 9:00–17:00...
# Email/sito                                                             n/d
# Name: 46, dtype: object
# ASL                                                                 ROMA 4
# Consultorio Familiare                     CONSULTORIO FAMILIARE ANGUILLARA
# Indirizzo                   VIA MARCO POLO, SNC, 00061, ANGUILLARA SABAZIA
# Telefono                                               06 96669771-772-773
# Orari                    Lun 8:00–17:00; Mar 8:00–13:30; Mer 8:00–17:00...
# Email/sito                                                             n/d
# Name: 49, dtype: object
# ASL                                                               ROMA 4
# Consultorio Familiare                     CONSULTORIO FAMILIARE FORMELLO
# Indirizzo                    VIA REGINA MARGHERITA, snc, 00060, FORMELLO
# Telefono                                                     06 96669337
# Orari                    Lun 8:30–13:30; Mar 8:30–13:30; Ven 8:30–13:30;
# Email/sito                                                           n/d
# Name: 52, dtype: object
# ASL                                                                 ROMA 4
# Consultorio Familiare                   CONSULTORIO FAMILIARE FIANO ROMANO
# Indirizzo                Via Tiberina n.71 angolo Capocroce, 00065, FIA...
# Telefono                                               06 96669110-111-112
# Orari                    Lun 8:30–14:00; Mar 8:30–17:00; Mer 8:30-14:00...
# Email/sito                                                             n/d
# Name: 53, dtype: object
# ASL                                                                 ROMA 4
# Consultorio Familiare                        CONSULTORIO FAMILIARE MORLUPO
# Indirizzo                            Via G. Roncacci, n.78, 00067, MORLUPO
# Telefono                                                       06 96669938
# Orari                    Lun 8:30–15:00; Mar 8:30–15:00; Mer 8:30-17:30...
# Email/sito                                                             n/d
# Name: 54, dtype: object
# ASL                                                      ROMA 5
# Consultorio Familiare         CONSULTORIO FAMILIARE FONTE NUOVA
# Indirizzo                Via IV Novembre, 2, 00013, FONTE NUOVA
# Telefono                                                    n/d
# Orari                                                       n/d
# Email/sito                                                  n/d
# Name: 56, dtype: object
# ASL                                                              ROMA 5
# Consultorio Familiare                 CONSULTORIO FAMILIARE  SETTEVILLE
# Indirizzo                Via G. Pascoli, 54, 00012, GUIDONIA MONTECELIO
# Telefono                                                    0774 391375
# Orari                                Lun-Ven 8:30–13:00; Mar 8:30–19:00
# Email/sito                           consultorio.setteville@aslroma5.it
# Name: 57, dtype: object
# ASL                                                                 ROMA 5
# Consultorio Familiare                         CONSULTORIO PALOMBARA SABINA
# Indirizzo                Piazza Salvo d'Acquisto, 1, 00018, PALOMBARA S...
# Telefono                                                    0774 654 54 20
# Orari                                   Lun-Ven 8:30–13:00; Gio 8:00–18:00
# Email/sito                               consultorio.palombara@aslroma5.it
# Name: 59, dtype: object
# ASL                                                           ROMA 5
# Consultorio Familiare    DISTRETTO DI SUBIACO CON CONSULTORIO E SERD
# Indirizzo                           LARGO MAZZINI, 5, 00028, SUBIACO
# Telefono                                                0774824142/3
# Orari                        Lun-Ven 8:00–13:00; Mar, Gio 8:00–17:00
# Email/sito                           consultorio.subiaco@aslroma5.it
# Name: 61, dtype: object
# ASL                                                                 ROMA 5
# Consultorio Familiare    PRESIDIO DI OLEVANO ROMANO CON CONSULTORIO E T...
# Indirizzo                via di S. Francesco D'Assisi snc, 00025, OLEVA...
# Telefono                                                               n/d
# Orari                                                                  n/d
# Email/sito                                                             n/d
# Name: 62, dtype: object
# ASL                                                             ROMA 5
# Consultorio Familiare    CASA DELLA SALUTE DI ZAGAROLO CON CONSULTORIO
# Indirizzo                   VIA BORGO SAN MARTINO SNC, 00039, ZAGAROLO
# Telefono                                                   06 95322841
# Orari                          Lun-Ven 8:00–13:00; Mar, Gio 8:00–17:30
# Email/sito                            consultorio.zagarolo@aslroma5.it
# Name: 64, dtype: object
# ASL                                                       ROMA 5
# Consultorio Familiare          CONSULTORIO FAMILIARE  COLLEFERRO
# Indirizzo                   Largo Oberdan snc, 00034, COLLEFERRO
# Telefono                                             06 97206750
# Orari                    Lun-Ven 8:00–15:00; Lun, Gio 8:00–17:30
# Email/sito                    consultorio.colleferro@aslroma5.it
# Name: 65, dtype: object
# ASL                                              ROMA 5
# Consultorio Familiare                 CONSULTORIO SEGNI
# Indirizzo                Via Pacinotti, 1, 00037, SEGNI
# Telefono                                            n/d
# Orari                                               n/d
# Email/sito                                          n/d
# Name: 67, dtype: object
# ASL                                                                 ROMA 6
# Consultorio Familiare                   CONSULTORIO FAMILIARE ROCCA PRIORA
# Indirizzo                VIA MALPASSO D`ACQUA c/o ospedale Cartoni, 000...
# Telefono                                                      06/932724131
# Orari                         Lun, Gio, Ven 8:30–13:00; Mar,Mer 8:00-16:30
# Email/sito                                                             n/d
# Name: 69, dtype: object
# ASL                                                                ROMA 6
# Consultorio Familiare                        CONSULTORIO FAMILIARE MARINO
# Indirizzo                Vle XXIV maggio ,1 c\o osp Marino, 00047, MARINO
# Telefono                                                     06 932724131
# Orari                       Lun, Gio, Ven 8:30–13:00; Mar, Mer 8:00-16:30
# Email/sito                                                            n/d
# Name: 73, dtype: object
# ASL                                                             ROMA 6
# Consultorio Familiare                   CONSULTORIO FAMILIARE CIAMPINO
# Indirizzo                              via m. Calo' 5, 00043, CIAMPINO
# Telefono                                                  06 932724132
# Orari                    Lun, Gio, Ven 8:30–13:00; Mar, Mer 8:00-16:30
# Email/sito                                                         n/d
# Name: 74, dtype: object
# ASL                                                              ROMA 6
# Consultorio Familiare                      CONSULTORIO FAMILIARE ALBANO
# Indirizzo                VIA GALLERIA DI SOTTO 6, 00041, ALBANO LAZIALE
# Telefono                                                    06 93273352
# Orari                     Lun, Gio, Ven 8:30–13:00; Mar, Mer 8:00-16:30
# Email/sito                                                          n/d
# Name: 77, dtype: object
# ASL                                                             ROMA 6
# Consultorio Familiare                    CONSULTORIO FAMILIARE ARICCIA
# Indirizzo                      VIA ANTONIETTA CHIGI 52, 00040, ARICCIA
# Telefono                                                   06 93273352
# Orari                    Lun, Gio, Ven 8:30–13:00; Mar, Mer 8:00-16:30
# Email/sito                                                         n/d
# Name: 79, dtype: object
# ASL                                                             ROMA 6
# Consultorio Familiare                    CONSULTORIO FAMILIARE LANUVIO
# Indirizzo                           VIA ALDO MORO 8/12, 00040, LANUVIO
# Telefono                                                   06 93273352
# Orari                    Lun, Gio, Ven 8:30–13:00; Mar, Mer 8:00-16:30
# Email/sito                                                         n/d
# Name: 80, dtype: object
# ASL                                                               ROMA 6
# Consultorio Familiare              CONSULTORIO FAMILIARE GIOVANI GENZANO
# Indirizzo                VIA UNIONE SOVIETICA 14, 00045, GENZANO DI ROMA
# Telefono                                                     06 93273352
# Orari                      Lun, Gio, Ven 8:30–13:00; Mar, Mer 8:00-16:30
# Email/sito                                                           n/d
# Name: 81, dtype: object
# ASL                                                                 ROMA 6
# Consultorio Familiare                        CONSULTORIO FAMILIARE NETTUNO
# Indirizzo                PIAZZA SAN FRANCESCO( C/O POL BARBERINI), 0004...
# Telefono                                                       06 93272433
# Orari                        Lun, Gio, Ven 8:30–13:00; Mar, Mer 8:00-16:30
# Email/sito                                                             n/d
# Name: 82, dtype: object

# %%
# Aggiungi una legenda alla mappa
legend_html = f'''
<div style="position: fixed; 
            bottom: 50px; left: 50px; width: fit-content; height: fit-content; 
            background-color: white; z-index:9999; font-size:14px; opacity: 0.8; border-radius: 6px;
            border:2px solid grey; padding: 10px;">
    <b>Legenda ASL</b><br>
    <img src="./blue.png" height={icon_height} width={icon_width}></img> ROMA 1<br>
    <img src="./green.png" height={icon_height} width={icon_width}></img> ROMA 2<br>
    <img src="./red.png" height={icon_height} width={icon_width}></img> ROMA 3<br>
    <img src="./purple.png" height={icon_height} width={icon_width}></img> ROMA 4<br>
    <img src="./orange.png" height={icon_height} width={icon_width}></img> ROMA 5<br>
    <img src="./darkred.png" height={icon_height} width={icon_width}></img> ROMA 6<br>
</div>
'''
roma_map.get_root().html.add_child(folium.Element(legend_html))

# %%
# Salvataggio della mappa in un file HTML nella stessa directory del file CSV
output_path = os.path.join(os.path.dirname(file_path), 'consultori_roma_map_searchbar.html')
roma_map.save(output_path)
print(f"Mappa salvata come {output_path}")
# Out:
# Mappa salvata come ./consultori_roma_map_searchbar.html
